# %%
import cvxpy as cp
import numpy as np
from analyze_stability import * 
from scipy import linalg

# %%
pip install matplotlib

# %% [markdown]
# ### Parameter Setting:
#
# #### Generator Parameter Setting
# - $ T_{v} $ = Time constant of valve
# - $ T_{e} $ = Time constant of engine
# - $ H $ = Inertia Constant
# - $ D $ = Fractional Constant
#
# - $ M $ = $ 2\sum_i H_{i}$

# %%
Ts = 0.5*10**-4
wpu = 1.0;
Wmax = 1.02;

# Generator Parameter
Pgen = np.array([1, 1, 1])
droop = 0.05
Tv = np.array([0.5, 1.0, 1.0])
Te = np.array([0.05, 0.1, 0.1])
H = np.array([1.587, 2.5, 2.5])
D = 0.01
gen_dict = {'Sbase':150, 'Pgen':Pgen, 'droop':droop,
            'Tv':Tv, 'Te':Te, 'H':H, 'D':D}

# Control Parameter
con_dict = {'kp1': 8,
            'ki1': 2.5,
            'ki2': 5,
            'kc1' : 0.1,
            'Tl1' : 2.4
           }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23352\1643197123.py in <module>
#       4
#       5 # Generator Parameter
# ----> 6 Pgen = np.array([1, 1, 1])
#       7 droop = 0.05
#       8 Tv = np.array([0.5, 1.0, 1.0])
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Generate System Matrix

# %%
# Ngen  number of generator
# Nval  number of variables for one generator
Ts = 0.5*10**-4
error_mat = np.array([0.0001, 0, -0.0001])
scenario = 'droop'
case_dict = {'Ngen':3, 'Nval': cal_Nvariable(scenario), 'Ts': 0.5*10**-4, 'Ttotal': 200,
            'wpu':1.0, 'Wmax': 1.02, 'error': error_mat}

A = generate_Amat(gen_dict, con_dict, case_dict, scenario)
B = generate_Bmat(gen_dict, con_dict, case_dict)

# %% [markdown]
# ### Analyze Eigen Value

# %%
eig,left_eig_v,right_eig_v = linalg.eig(A, left= True, right = True)

# %%
import matplotlib.pyplot as plt
plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
x = eig.real
y = eig.imag
plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
plt.xlim([-2.5, 0.5])
plt.ylim([ -3, 3])
# Out:
# (-3.0, 3.0)

# %%
X_droop, U1, U2 = run_timeseries(gen_dict, con_dict, case_dict, 'droop')

#Update Plot
draw_graph(X_droop, gen_dict, case_dict, scenario)
# Out:
# Simulation Time: 74.178537607193 secs
# Draw the Frequency Plot
# Draw the Active Power Plot

# %%
case_dict['Nval'] = cal_Nvariable(scenario)
X_secPI, U1, U2 = run_timeseries(gen_dict, con_dict, case_dict, 'secondPI')

#Update Plot
draw_graph(X_secPI, gen_dict, case_dict, 'secondPI')
# Out:
# Simulation Time: 72.4806592464447 secs
# Draw the Frequency Plot
# Draw the Wref Plot
# Draw the Active Power Plot

# %%
case_dict['Nval'] = cal_Nvariable(scenario)
X_secPI, U1, U2 = run_timeseries(gen_dict, con_dict, case_dict, 'nudge')

#Update Plot
draw_graph(X_secPI, gen_dict, case_dict, 'nudge')
# Out:
# Simulation Time: 103.20378136634827 secs
# Draw the Frequency Plot
# Draw the Wref Plot
# Draw the Active Power Plot

# %%
X_nudge, U1, U2 = run_timeseries(gen_dict, con_dict, case_dict, 'nudge')
