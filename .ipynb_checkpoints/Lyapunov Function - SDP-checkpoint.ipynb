736565</td><td style="text-align: right;">-0.0664622</td><td style="text-align: right;"> 0.0512002</td><td style="text-align: right;">-0.068246   </td><td style="text-align: right;"> 0.000734277</td><td style="text-align: right;">-0.0665068</td><td style="text-align: right;"> 0.0512086</td></tr>\n<tr><td style="text-align: right;">-0.0824249</td><td style="text-align: right;"> 0.00073399 </td><td style="text-align: right;"> 0.0122839 </td><td style="text-align: right;">-0.0162286</td><td style="text-align: right;">-0.0710058</td><td style="text-align: r ...

# %%
X_droop, U = run_timeseries(gen_dict, con_dict, case_dict, 'droop')

#Update Plot
draw_graph(X_droop, gen_dict, case_dict, scenario)

droop_set = {'X':X_droop, 'P':P.value, 'A_droop': A, 'A': A, 'B':B, 'U':U}
V_droop, V_dot_droop, V_input_dot_droop = draw_lyapunov(droop_set, case_dict)
# Out:
# A matrix change from droop to droop
# Simulation Time: 39.25335693359375 secs
# Draw the Frequency Plot
# Draw the Active Power Plot
# Lyapunov Simulation Time: 5.885346174240112 secs
# Print_lyapunov_function for timeseries
# Change A matrix from droop to the other set
# Draw Lyapunov function
# Draw the derivative of lyapunov function
# Consider the input matrix

# %% [markdown]
# ### Case 2
# ### Minimize(cp.trace(P)), , A_T@P + P@A << 0

# %%
n = A.shape[0]

# Define the LMI variables
#P = cp.Variable((n,n), symmetric = True, PSD = True)
P = cp.Variable((n,n), symmetric = True)
gamma = 1.0* 1e-6
Q = np.eye(n)* gamma
# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P - 1e-6*np.eye(n)>> 0, A.T @ P + P@A << 0]

# Define the objective for the LMI optimization problem
obj = cp.Minimize(cp.trace(P))
#obj = cp.Minimize(cp.norm(P,1))

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
prob.solve(solver=cp.MOSEK, verbose=True)

P_value = np.round(P.value, decimals=7)
eig,left_eig_v,right_eig_v = linalg.eig(P_value, left= True, right = True)
check_symmetric(P_value)

eig, eig_vec = linalg.eig(P_value)
print("Eigen Value of P ")
plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

x = eig.real
y = eig.imag

print("minimum eigenvalue of P:", min(x))
print("maximum eigenvalue of P:", max(x))


plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 22 04:36:03 PM: Your problem has 169 variables, 2 constraints, and 0 parameters.
# (CVXPY) Mar 22 04:36:03 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 22 04:36:03 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 22 04:36:03 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 22 04:36:03 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 22 04:36:03 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 22 04:36:03 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 22 04:36:03 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 22 04:36:03 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 22 04:36:03 PM: Applying reduction MOSEK
# (CVXPY) Mar 22 04:36:03 PM: Finished problem compilation (took 2.400e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 22 04:36:03 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 22 04:36:03 PM: Problem
# (CVXPY) Mar 22 04:36:03 PM:   Name                   :
# (CVXPY) Mar 22 04:36:03 PM:   Objective sense        : maximize
# (CVXPY) Mar 22 04:36:03 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 22 04:36:03 PM:   Constraints            : 91
# (CVXPY) Mar 22 04:36:03 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 22 04:36:03 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 22 04:36:03 PM:   Cones                  : 0
# (CVXPY) Mar 22 04:36:03 PM:   Scalar variables       : 0
# (CVXPY) Mar 22 04:36:03 PM:   Matrix variables       : 2
# (CVXPY) Mar 22 04:36:03 PM:   Integer variables      : 0
# (CVXPY) Mar 22 04:36:03 PM:
# (CVXPY) Mar 22 04:36:03 PM: Optimizer started.
# (CVXPY) Mar 22 04:36:03 PM: Presolve started.
# (CVXPY) Mar 22 04:36:03 PM: Linear dependency checker started.
# (CVXPY) Mar 22 04:36:03 PM: Linear dependency checker terminated.
# (CVXPY) Mar 22 04:36:03 PM: Eliminator started.
# (CVXPY) Mar 22 04:36:03 PM: Freed constraints in eliminator : 0
# (CVXPY) Mar 22 04:36:03 PM: Eliminator terminated.
# (CVXPY) Mar 22 04:36:03 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Mar 22 04:36:03 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Mar 22 04:36:03 PM: Lin. dep.  - number                 : 0
# (CVXPY) Mar 22 04:36:03 PM: Presolve terminated. Time: 0.02
# (CVXPY) Mar 22 04:36:03 PM: Problem
# (CVXPY) Mar 22 04:36:03 PM:   Name                   :
# (CVXPY) Mar 22 04:36:03 PM:   Objective sense        : maximize
# (CVXPY) Mar 22 04:36:03 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 22 04:36:03 PM:   Constraints            : 91
# (CVXPY) Mar 22 04:36:03 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 22 04:36:03 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 22 04:36:03 PM:   Cones                  : 0
# (CVXPY) Mar 22 04:36:03 PM:   Scalar variables       : 0
# (CVXPY) Mar 22 04:36:03 PM:   Matrix variables       : 2
# (CVXPY) Mar 22 04:36:03 PM:   Integer variables      : 0
# (CVXPY) Mar 22 04:36:03 PM:
# (CVXPY) Mar 22 04:36:03 PM: Optimizer  - threads                : 8
# (CVXPY) Mar 22 04:36:03 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Mar 22 04:36:03 PM: Optimizer  - Constraints            : 91
# (CVXPY) Mar 22 04:36:03 PM: Optimizer  - Cones                  : 0
# (CVXPY) Mar 22 04:36:03 PM: Optimizer  - Scalar variables       : 0                 conic                  : 0
# (CVXPY) Mar 22 04:36:03 PM: Optimizer  - Semi-definite variables: 2                 scalarized             : 182
# (CVXPY) Mar 22 04:36:03 PM: Factor     - setup time             : 0.00              dense det. time        : 0.00
# (CVXPY) Mar 22 04:36:03 PM: Factor     - ML order time          : 0.00              GP order time          : 0.00
# (CVXPY) Mar 22 04:36:03 PM: Factor     - nonzeros before factor : 4186              after factor           : 4186
# (CVXPY) Mar 22 04:36:03 PM: Factor     - dense dim.             : 0                 flops                  : 4.05e+05
# (CVXPY) Mar 22 04:36:03 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Mar 22 04:36:03 PM: 0   1.0e+00  1.0e+00  1.0e+00  0.00e+00   1.300000000e-05   0.000000000e+00   1.0e+00  0.02
# (CVXPY) Mar 22 04:36:03 PM: 1   6.5e-02  6.5e-02  1.1e-02  1.07e+00   1.250884930e-05   3.033603988e-02   6.5e-02  0.02
# (CVXPY) Mar 22 04:36:03 PM: 2   7.8e-03  7.8e-03  4.1e-04  1.06e+00   1.227804498e-05   4.077178486e-03   7.8e-03  0.02
# (CVXPY) Mar 22 04:36:03 PM: 3   7.4e-04  7.4e-04  1.1e-05  1.14e+00   1.231413840e-05   3.887933506e-04   7.4e-04  0.02
# (CVXPY) Mar 22 04:36:03 PM: 4   2.0e-06  2.0e-06  1.8e-09  1.03e+00   1.237659158e-05   1.314344706e-05   2.0e-06  0.02
# (CVXPY) Mar 22 04:36:03 PM: 5   5.5e-07  5.5e-07  7.8e-10  1.81e-01   3.767664712e-05   3.700442742e-05   5.5e-07  0.03
# (CVXPY) Mar 22 04:36:03 PM: 6   1.3e-07  1.3e-07  2.6e-10  -2.77e-01  1.083991668e-04   1.054467708e-04   1.3e-07  0.03
# (CVXPY) Mar 22 04:36:03 PM: 7   3.4e-08  3.4e-08  6.4e-11  -1.97e-01  1.973209020e-04   1.943164348e-04   3.4e-08  0.03
-05 </td><td style="text-align: right;">-6.98332e-05</td><td style="text-align: right;"> 7.955e-06  </td><td style="text-align: right;"> 5.885e-06  </td><td style="text-align: right;"> 1.4535e-05 </td></tr>\n<tr><td style="text-align: right;">-0.000271219</td><td style="text-align: right;">-4.26008e-05</td><td style="text-align: right;">-0.000100055</td><td style="text-align: right;">-5.78e-05   </td><td style="text-align: right;"> 0.0002461  </td><td style="text-align: right;">-4.26008e-05</td><td style="text-align: right;">-3.575e-06  </td><td style="text-align: right;">-6e-07      </td><td style="text-align: right;"> 1.38e-05   </td><td style="text-align: right;">-4.26008e-05</td><td style="text-align: right;">-3.575e-06  </td><td style="text-align: right;">-6e-07      </td><td style="text-align: right;"> 1.38e-05   </td></tr>\n<tr><td style="text-align: right;"> 0.00114484 </td><td style="text-align: right;"> 0.000178687</td><td style="text-align: right;"> 0.00042498 </td><td style="text-align: right;"> 0.0002461  </td><td style="text-align: right;">-0.0010496  </td><td style="text-align: right;"> 0.000178687</td><td style="text-align: right;"> 1.363e-05  </td><td style="text-align: right;">-1.1e-06    </td><td style="text-align: right;">-5.44e-05   </td><td style="text-align: right;"> 0.000178687</td><td style="text-align: right;"> 1.363e-05  </td><td style="text-align: right;">-1.1e-06    </td><td style="text-align: right;">-5.44e-05   </td></tr>\n<tr><td style="text-align: right;">-0.000244871</td><td style="text-align: right;">-3.8576e-05 </td><td style="text-align: right;">-6.98332e-05</td><td style="text-align: right;">-4.26008e-05</td><td style="text-align: right;"> 0.000178687</td><td style="text-align: right;">-3.8576e-05 </td><td style="text-align: right;">-1.22867e-05</td><td style="text-align: right;">-1.07617e-05</td><td style="text-align: right;"> 3.41982e-05</td><td style="text-align: right;">-3.8576e-05 </td><td style="text-align: right;">-1.22967e-05</td><td style="text-align: right;">-1.07617e-05</td><td style="text-align: right;"> 3.41982e-05</td></tr>\n<tr><td style="text-align: right;">-7.83924e-05</td><td style="text-align: right;">-1.22967e-05</td><td style="text-align: right;"> 7.955e-06  </td><td style="text-align:  ...

# %%
X_droop, U = run_timeseries(gen_dict, con_dict, case_dict, 'droop')

#Update Plot
draw_graph(X_droop, gen_dict, case_dict, scenario)

droop_set = {'X':X_droop, 'P':P_value, 'A_droop': A, 'A': A, 'B':B, 'U':U}
V_droop, V_dot_droop, V_input_dot_droop = draw_lyapunov(droop_set, case_dict)
# Out:
# A matrix change from droop to droop
# Simulation Time: 38.93999910354614 secs
# Draw the Frequency Plot
# Draw the Active Power Plot
# Lyapunov Simulation Time: 6.0020012855529785 secs
# Print_lyapunov_function for timeseries
# Change A matrix from droop to the other set
# Draw Lyapunov function
# Draw the derivative of lyapunov function
# Consider the input matrix

# %% [markdown]
# ### Case 3
# ### Minimize(cp.trace(P)), , A_T@P + P@A + Q << 0
# #### Q -> cp variable

# %%
n = A.shape[0]

# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma = 1.0* 1e-6
Q = np.eye(n)* gamma
Q = cp.Variable((n,n), symmetric = True)

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P >>0, Q >>0, A.T @ P + P@A + Q << 0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(cp.trace(P))

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
prob.solve(solver=cp.MOSEK)

P_value = np.round(P.value, decimals=5)
Q_value = np.round(Q.value, decimals=5)
eig,left_eig_v,right_eig_v = linalg.eig(P_value, left= True, right = True)
check_symmetric(P_value)
check_symmetric(Q_value)

eig, eig_vec = linalg.eig(P_value)
print("Eigen Value of P ")
plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

x = eig.real
y = eig.imag

print("minimum eigenvalue of P:", min(x))
print("maximum eigenvalue of P:", max(x))


plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
# Out:
# Matrix is symmetric
# Matrix is symmetric
# Eigen Value of P
# minimum eigenvalue of P: 0.0
# maximum eigenvalue of P: 0.0

# %%
table = tabulate.tabulate(Q.value, tablefmt='html')
print("symmetric Q Table")
table
# Out:
# symmetric Q Table
# '<table>\n<tbody>\n<tr><td style="text-align: right;"> 2.34083e-06</td><td style="text-align: right;"> 5.70943e-07</td><td style="text-align: right;"> 1.20257e-06</td><td style="text-align: right;"> 5.10949e-07</td><td style="text-align: right;">-2.23125e-06</td><td style="text-align: right;">-1.49911e-21</td><td style="text-align: right;"> 5.60039e-07</td><td style="text-align: right;"> 4.12246e-08</td><td style="text-align: right;"> 4.94421e-08</td><td style="text-align: right;">-1.1493e-07 </td><td style="text-align: right;"> 6.00211e-24</td></tr>\n<tr><td style="text-align: right;"> 5.70943e-07</td><td style="text-align: right;"> 1.3915e-07 </td><td style="text-align: right;"> 2.97973e-07</td><td style="text-align: right;"> 1.249e-07  </td><td style="text-align: right;">-5.43197e-07</td><td style="text-align: right;">-3.44739e-22</td><td style="text-align: right;"> 1.3648e-07 </td><td style="text-align: right;"> 1.05444e-08</td><td style="text-align: right;"> 1.21196e-08</td><td style="text-align: right;">-2.87748e-08</td><td style="text-align: right;"> 1.66164e-24</td></tr>\n<tr><td style="text-align: right;"> 1.20257e-06</td><td style="text-align: right;"> 2.97973e-07</td><td style="text-align: right;"> 6.25343e-07</td><td style="text-align: right;"> 2.69116e-07</td><td style="text-align: right;">-1.16074e-06</td><td style="text-align: right;">-7.90958e-22</td><td style="text-align: right;"> 2.87569e-07</td><td style="text-align: right;"> 1.34209e-08</td><td style="text-align: right;"> 2.26989e-08</td><td style="text-align: right;">-4.49747e-08</td><td style="text-align: right;"> 2.74129e-24</td></tr>\n<tr><td style="text-align: right;"> 5.10949e-07</td><td style="text-align: right;"> 1.249e-07  </td><td style="text-align: right;"> 2.69116e-07</td><td style="text-align: right;"> 1.06384e-07</td><td style="text-align: right;">-4.95655e-07</td><td style="text-align: right;">-3.01898e-22</td><td style="text-align: right;"> 1.21993e-07</td><td style="text-align: right;"> 3.45394e-09</td><td style="text-align: right;"> 7.88572e-09</td><td style="text-align: right;">-1.64936e-08</td><td style="text-align: right;"> 2.15514e-24</td></tr>\n<tr><td style="text-align: right;">-2.23125e-06</td><td style="text-align: right;">-5.43197e-07</td><td style="text-align: right;">-1.16074e-06</td><td style="text-align: right;">-4.95655e-07</td><td style="text-align: right;"> 2.15728e-06</td><td style="text-align: right;"> 1.62472e-21</td><td style="text-align: right;">-5.33895e-07</td><td style="text-align: right;">-2.39356e-08</td><td style="text-align: right;">-4.05152e-08</td><td style="text-align: right;"> 7.94767e-08</td><td style="text-align: right;">-4.05201e-24</td></tr>\n<tr><td style="text-align: right;">-1.49911e-21</td><td style="text-align: right;">-3.44739e-22</td><td style="text-align: right;">-7.90958e-22</td><td style="text-align: right;">-3.01898e-22</td><td style="text-align: right;"> 1.62472e-21</td><td style="text-align: right;">-1.81837e-20</td><td style="text-align: right;">-4.13136e-22</td><td style="text-align: right;"> 3.56917e-23</td><td style="text-align: right;"> 6.48847e-23</td><td style="text-align: right;">-1.10797e-22</td><td style="text-align: right;"> 2.66053e-22</td></tr>\n<tr><td style="text-align: right;"> 5.60039e-07</td><td style="text-align: right;"> 1.3648e-07 </td><td style="text-align: right;"> 2.87569e-07</td><td style="text-align: right;"> 1.21993e-07</td><td style="text-align: right;">-5.33895e-07</td><td style="text-align: right;">-4.13136e-22</td><td style="text-align: right;"> 1.3381e-07 </td><td style="text-align: right;"> 1.39516e-08</td><td style="text-align: right;"> 1.20476e-08</td><td style="text-align: right;">-2.71474e-08</td><td style="text-align: right;"> 1.51335e-24</td></tr>\n<tr><td style="text-align: right;"> 4.12246e-08</td><td style="text-align: right;"> 1.05444e-08</td><td style="text-align: right;"> 1.34209e-08</td><td style="text-align: right;"> 3.45394e-09</td><td style="t ...

# %% [markdown]
# ### Case 4
# ### Minimize(cp.trace(P)), , A_T@P + P@A + Q << 0
# #### Q -> eye(n)

# %%
n = A.shape[0]

# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma = 1.0
Q = np.eye(n)

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P >>0, A.T @ P + P@A + Q << 0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(cp.trace(P))

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
sol = prob.solve(solver=cp.MOSEK)

if not m.isinf(sol):
    P_value = np.round(P.value, decimals=5)
    eig,left_eig_v,right_eig_v = linalg.eig(P_value, left= True, right = True)
    check_symmetric(P_value)

    eig, eig_vec = linalg.eig(P_value)
    print("Eigen Value of P ")
    plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
    plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

    x = eig.real
    y = eig.imag

    print("minimum eigenvalue of P:", min(x))
    print("maximum eigenvalue of P:", max(x))

    plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
else:
    print("Infinitity Solution - cannot solved")
# Out:
# Infinitity Solution - cannot solved

# %% [markdown]
# ### Case 5
# ### Minimize(0),  A_T@P + P@A + Q << 0
# #### Q -> eye(n)

# %%
n = A.shape[0]

# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma = 1.0
Q = np.eye(n)

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P >>0, A.T @ P + P@A + Q << 0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(0)

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
sol = prob.solve(solver=cp.MOSEK)

if not m.isinf(sol):
    P_value = np.round(P.value, decimals=5)
    eig,left_eig_v,right_eig_v = linalg.eig(P_value, left= True, right = True)
    check_symmetric(P_value)

    eig, eig_vec = linalg.eig(P_value)
    print("Eigen Value of P ")
    plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
    plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

    x = eig.real
    y = eig.imag

    print("minimum eigenvalue of P:", min(x))
    print("maximum eigenvalue of P:", max(x))

    plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
else:
    print("Infinitity Solution - cannot solved")
# Out:
# Infinitity Solution - cannot solved

# %% [markdown]
# ### Case 6
# ### Minimize(0),  A_T@P + P@A + r*Q << 0
# #### Try to find gaama that converged, Q -> eye(n)

# %%
n = A.shape[0]

# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma = 1.0
Q = np.eye(n)

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P >>0, A.T @ P + P@A + Q << 0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(0)

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
sol = prob.solve(solver=cp.MOSEK)

iter = 0
prev_iter = 0
now_iter = 0
while True:
    
    if not m.isinf(sol):
        break
    try:
        now_iter = iter
        n_niter = len(str(now_iter)) 
        n_piter = len(str(prev_iter))
        if n_niter - n_piter > 0:
            print('*'*n_niter)

        prev_iter = now_iter

        gamma -= 0.000001
        if gamma <= 0:
            print("gamma goes to zero")
            break

        constraints = [P >>0, A.T @ P + P@A + gamma*Q << 0]
        prob = cp.Problem(obj, constraints)    
        sol = prob.solve(solver=cp.MOSEK)

        iter += 1
    except:
        print('gamma:',gamma)
        print('Cannot Solved')
        break
print("iteration:", iter)
    
if not m.isinf(sol):
    P_value = np.round(P.value, decimals=5)
    eig,left_eig_v,right_eig_v = linalg.eig(P_value, left= True, right = True)
    check_symmetric(P_value)

    eig, eig_vec = linalg.eig(P_value)
    print("Eigen Value of P ")
    plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
    plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

    x = eig.real
    y = eig.imag

    print("minimum eigenvalue of P:", min(x))
    print("maximum eigenvalue of P:", max(x))

    plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
else:
    print("Infinitity Solution - cannot solved")
# Out:
# **
# ***
# ****
# *****
# ******
# gamma: 0.3075539999907712
# Cannot Solved
# iteration: 692445
# Infinitity Solution - cannot solved

# %%
n = A.shape[0]

# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma = 1.0
Q = np.eye(n)

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P >>0, A.T @ P + P@A + 0.00213899 * Q << 0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(0)

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
sol = prob.solve(solver=cp.MOSEK)

# %%
print("Print_lyapunov_function for timeseries")

nTime = X_droop.shape[1]
x = np.arange(nTime)*Ts 
V = np.zeros([nTime]) 

P_value = P.value
for i in range(nTime):
    temp = np.dot(X_droop[:,i].T, P_value)
    V[i] = np.dot(temp, X_droop[:,i])

plt.plot(x,V, label='V(x)', color = 'black', alpha = 0.7)
plt.legend(loc='best', fontsize=10)
plt.ylabel('V(x)')
plt.xlabel('Time [s]')
plt.show()
# Out:
# Print_lyapunov_function for timeseries

# %% [markdown]
# ### Case 7
# ### Secondary PI System
# ### Minimize(0),  A_T@P + P@A << 0

# %%
A = generate_Amat(gen_dict, con_dict, case_dict, 'secondPI')
eig,left_eig_v,right_eig_v = linalg.eig(A, left= True, right = True)

plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
x = eig.real
y = eig.imag
plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
plt.xlim([-2.5, 0.5])
plt.ylim([ -3, 3])
# Out:
# (-3.0, 3.0)

# %%
Ts = 0.5*10**-4

A_droop = generate_Amat(gen_dict, con_dict, case_dict, 'droop')
A = generate_Amat(gen_dict, con_dict, case_dict, 'secondPI')
n = A.shape[0]

# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma = 1e-6
G = np.eye(n)* gamma
# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P >> G, A.T @ P + P@A << 0 ]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(0)

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
prob.solve(solver=cp.MOSEK)

P_value = np.round(P.value, decimals=5)
eig,left_eig_v,right_eig_v = linalg.eig(P_value, left= True, right = True)
check_symmetric(P_value)

eig, eig_vec = linalg.eig(P_value)
print("Eigen Value of P ")
plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

x = eig.real
y = eig.imag

print("minimum eigenvalue of P:", min(x))
print("maximum eigenvalue of P:", max(x))


plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
# Out:
# Matrix is symmetric
# Eigen Value of P
# minimum eigenvalue of P: 0.006588760007429893
# maximum eigenvalue of P: 6.663088183232203

# %%
X_secPI, U = run_timeseries(gen_dict, con_dict, case_dict, 'secondPI')

#Update Plot
draw_graph(X_secPI, gen_dict, case_dict, scenario)

A_droop = generate_Amat(gen_dict, con_dict, case_dict, 'droop')
A = generate_Amat(gen_dict, con_dict, case_dict, 'secondPI')
B = generate_Bmat(gen_dict, con_dict, case_dict)
second_PI_set = {'X':X_secPI, 'P':P.value, 'A_droop': A_droop, 'A': A, 'B':B,
                'U': U}
V_secPI, V_dot_secPI, V_input_dot_secPI = draw_lyapunov(second_PI_set, case_dict)
# Out:
# A matrix change from droop to secondPI
# Simulation Time: 41.24240827560425 secs
# Draw the Frequency Plot
# Draw the Wref Plot
# Draw the Active Power Plot
# Lyapunov Simulation Time: 10.854145288467407 secs
# Print_lyapunov_function for timeseries
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [44], in <cell line: 10>()
#       7 A = generate_Amat(gen_dict, con_dict, case_dict, 'secondPI')
#       8 second_PI_set = {'X':X_secPI, 'P':P.value, 'A_droop': A_droop, 'A': A, 'B':B,
#       9                 'U': U}
# ---> 10 V_secPI, V_dot_secPI, V_input_dot_secPI = draw_lyapunov(second_PI_set, case_dict)
#
# File ~\OneDrive\Desktop\Project\Lyapunov_SDP_Stability\analyze_stability.py:280, in draw_lyapunov(matrix_set, case)
#     276 temp_Vdot = np.dot(X[:,i].T, temp_APPA)
#     278 V_dot[i] = np.dot(temp_Vdot, X[:,i])
# --> 280 temp_PB = np.dot(P, B)
#     281 temp_xPB = np.dot(X[:,i].T, temp_PB)
#     282 V_input_dot[i] = 2*np.dot(temp_xPB, U[:,i])
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# ValueError: shapes (19,19) and (13,4) not aligned: 19 (dim 1) != 13 (dim 0)

# %% [markdown]
# ### Case 8
# ### Secondary PI System
# ### Minimize(0),  A_T@P + P@A + 2PBU << 0

# %%
A = generate_Amat(gen_dict, con_dict, case_dict, 'droop')
B = generate_Bmat(gen_dict, con_dict, case_dict)

n = A.shape[0]

# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma = 1e-6
Q = np.eye(n)* gamma

U = np.array([0.05, 0.0005, -0.0005]).T

bias = LN.norm(np.dot(B,U),2)*2*0.05

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P >> Q, A.T @ P + P@A + 2*bias*P  << 0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(0)

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
prob.solve(solver=cp.MOSEK, verbose = True)

P_value = np.round(P.value, decimals=5)
eig,left_eig_v,right_eig_v = LN.eig(P_value, left= True, right = True)
check_symmetric(P_value)

eig, eig_vec = LN.eig(P_value)
print("Eigen Value of P ")
plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

x = eig.real
y = eig.imag

print("minimum eigenvalue of P:", min(x))
print("maximum eigenvalue of P:", max(x))


plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 09 03:49:39 PM: Your problem has 81 variables, 2 constraints, and 0 parameters.
# (CVXPY) Mar 09 03:49:39 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 09 03:49:39 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 09 03:49:39 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 09 03:49:39 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 09 03:49:39 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 09 03:49:39 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 09 03:49:39 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 09 03:49:39 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 09 03:49:39 PM: Applying reduction MOSEK
# (CVXPY) Mar 09 03:49:39 PM: Finished problem compilation (took 1.900e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 09 03:49:39 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 09 03:49:39 PM: Problem
# (CVXPY) Mar 09 03:49:39 PM:   Name                   :
# (CVXPY) Mar 09 03:49:39 PM:   Objective sense        : maximize
# (CVXPY) Mar 09 03:49:39 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 09 03:49:39 PM:   Constraints            : 45
# (CVXPY) Mar 09 03:49:39 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 09 03:49:39 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 09 03:49:39 PM:   Cones                  : 0
# (CVXPY) Mar 09 03:49:39 PM:   Scalar variables       : 0
# (CVXPY) Mar 09 03:49:39 PM:   Matrix variables       : 2
# (CVXPY) Mar 09 03:49:39 PM:   Integer variables      : 0
# (CVXPY) Mar 09 03:49:39 PM:
# (CVXPY) Mar 09 03:49:39 PM: Optimizer started.
# (CVXPY) Mar 09 03:49:39 PM: Presolve started.
# (CVXPY) Mar 09 03:49:39 PM: Linear dependency checker started.
# (CVXPY) Mar 09 03:49:39 PM: Linear dependency checker terminated.
# (CVXPY) Mar 09 03:49:39 PM: Eliminator started.
# (CVXPY) Mar 09 03:49:39 PM: Freed constraints in eliminator : 0
# (CVXPY) Mar 09 03:49:39 PM: Eliminator terminated.
# (CVXPY) Mar 09 03:49:39 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Mar 09 03:49:39 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Mar 09 03:49:39 PM: Lin. dep.  - number                 : 0
# (CVXPY) Mar 09 03:49:39 PM: Presolve terminated. Time: 0.00
# (CVXPY) Mar 09 03:49:39 PM: Problem
# (CVXPY) Mar 09 03:49:39 PM:   Name                   :
# (CVXPY) Mar 09 03:49:39 PM:   Objective sense        : maximize
# (CVXPY) Mar 09 03:49:39 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 09 03:49:39 PM:   Constraints            : 45
# (CVXPY) Mar 09 03:49:39 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 09 03:49:39 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 09 03:49:39 PM:   Cones                  : 0
# (CVXPY) Mar 09 03:49:39 PM:   Scalar variables       : 0
# (CVXPY) Mar 09 03:49:39 PM:   Matrix variables       : 2
# (CVXPY) Mar 09 03:49:39 PM:   Integer variables      : 0
# (CVXPY) Mar 09 03:49:39 PM:
# (CVXPY) Mar 09 03:49:39 PM: Optimizer  - threads                : 8
# (CVXPY) Mar 09 03:49:39 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Mar 09 03:49:39 PM: Optimizer  - Constraints            : 45
# (CVXPY) Mar 09 03:49:39 PM: Optimizer  - Cones                  : 0
# (CVXPY) Mar 09 03:49:39 PM: Optimizer  - Scalar variables       : 0                 conic                  : 0
# (CVXPY) Mar 09 03:49:39 PM: Optimizer  - Semi-definite variables: 2                 scalarized             : 90
# (CVXPY) Mar 09 03:49:39 PM: Factor     - setup time             : 0.00              dense det. time        : 0.00
# (CVXPY) Mar 09 03:49:39 PM: Factor     - ML order time          : 0.00              GP order time          : 0.00
# (CVXPY) Mar 09 03:49:39 PM: Factor     - nonzeros before factor : 1035              after factor           : 1035
# (CVXPY) Mar 09 03:49:39 PM: Factor     - dense dim.             : 0                 flops                  : 6.81e+04
# (CVXPY) Mar 09 03:49:39 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Mar 09 03:49:39 PM: 0   8.6e-01  1.0e+00  1.0e+00  0.00e+00   9.000000000e-06   0.000000000e+00   1.0e+00  0.00
# (CVXPY) Mar 09 03:49:39 PM: 1   1.7e-01  1.9e-01  8.5e-02  1.00e+00   5.368733657e-06   0.000000000e+00   1.9e-01  0.02
# (CVXPY) Mar 09 03:49:39 PM: 2   4.6e-02  5.4e-02  1.3e-02  1.00e+00   3.898507477e-06   0.000000000e+00   5.4e-02  0.02
# (CVXPY) Mar 09 03:49:39 PM: 3   1.1e-02  1.3e-02  1.5e-03  1.00e+00   2.542072325e-06   0.000000000e+00   1.3e-02  0.02
# (CVXPY) Mar 09 03:49:39 PM: 4   1.7e-03  2.0e-03  9.1e-05  1.00e+00   1.588497297e-06   0.000000000e+00   2.0e-03  0.02
# (CVXPY) Mar 09 03:49:39 PM: 5   2.9e-04  3.4e-04  6.2e-06  9.99e-01   9.813159286e-07   0.000000000e+00   3.4e-04  0.02
# (CVXPY) Mar 09 03:49:39 PM: 6   2.4e-05  2.8e-05  1.5e-07  9.95e-01   8.560539711e-07   0.000000000e+00   2.8e-05  0.02
# (CVXPY) Mar 09 03:49:39 PM: 7   9.8e-07  1.1e-06  1.6e-09  9.42e-01   9.019467167e-07   0.000000000e+00   1.1e-06  0.02
# (CVXPY) Mar 09 03:49:39 PM: 8   1.2e-07  1.4e-07  2.5e-10  5.08e-02   3.118874738e-06   0.000000000e+00   1.4e-07  0.02
# (CVXPY) Mar 09 03:49:39 PM: 9   1.4e-09  1.7e-09  2.7e-11  -8.74e-01  2.714536926e-04   0.000000000e+00   1.7e-09  0.02
# (CVXPY) Mar 09 03:49:39 PM: 10  1.3e-10  1.2e-08  7.3e-12  -1.00e+00  4.046882774e-03   0.000000000e+00   1.1e-10  0.02
# (CVXPY) Mar 09 03:49:39 PM: 11  1.5e-11  4.2e-08  2.5e-12  -1.04e+00  4.914208640e-02   0.000000000e+00   1.1e-11  0.02
# (CVXPY) Mar 09 03:49:39 PM: 12  2.3e-12  7.0e-07  9.6e-13  -1.08e+00  4.804462246e-01   0.000000000e+00   1.3e-12  0.03
# (CVXPY) Mar 09 03:49:39 PM: 13  2.3e-12  6.9e-07  9.5e-13  -1.05e+00  4.821982383e-01   0.000000000e+00   1.3e-12  0.03
# (CVXPY) Mar 09 03:49:39 PM: 14  2.3e-12  7.0e-07  9.5e-13  -1.05e+00  4.824173522e-01   0.000000000e+00   1.3e-12  0.03
# (CVXPY) Mar 09 03:49:39 PM: 15  2.3e-12  7.0e-07  9.5e-13  -1.05e+00  4.824173522e-01   0.000000000e+00   1.3e-12  0.03
# (CVXPY) Mar 09 03:49:39 PM: Optimizer terminated. Time: 0.05
# (CVXPY) Mar 09 03:49:39 PM:
# (CVXPY) Mar 09 03:49:39 PM:
# (CVXPY) Mar 09 03:49:39 PM: Interior-point solution summary
# (CVXPY) Mar 09 03:49:39 PM:   Problem status  : UNKNOWN
# (CVXPY) Mar 09 03:49:39 PM:   Solution status : UNKNOWN
# (CVXPY) Mar 09 03:49:39 PM:   Primal.  obj: 4.8241735223e-01    nrm: 8e+05    Viol.  con: 1e-04    barvar: 0e+00
# (CVXPY) Mar 09 03:49:39 PM:   Dual.    obj: 0.0000000000e+00    nrm: 2e+06    Viol.  con: 0e+00    barvar: 3e-01
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# Input In [66], in <cell line: 30>()
#      24 prob = cp.Problem(obj, constraints)
#      26 # Create a SolverOptions object and set the tolerance to 1e-6
#      27 # Solve the problem with the specified options
#      28
#      29 #prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
# ---> 30 prob.solve(solver=cp.MOSEK, verbose = True)
#      32 P_value = np.round(P.value, decimals=5)
#      33 eig,left_eig_v,right_eig_v = LN.eig(P_value, left= True, right = True)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:493, in Problem.solve(self, *args, **kwargs)
#     491 else:
#     492     solve_func = Problem._solve
# --> 493 return solve_func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:1068, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1066 end = time.time()
#    1067 self._solve_time = end - start
# -> 1068 self.unpack_results(solution, solving_chain, inverse_data)
#    1069 if verbose:
#    1070     print(_FOOTER)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:1393, in Problem.unpack_results(self, solution, chain, inverse_data)
#    1391     warnings.warn(INF_OR_UNB_MESSAGE)
#    1392 if solution.status in s.ERROR:
# -> 1393     raise error.SolverError(
#    1394             "Solver '%s' failed. " % chain.solver.name() +
#    1395             "Try another solver, or solve with verbose=True for more "
#    1396             "information.")
#    1398 self.unpack(solution)
#    1399 self._solver_stats = SolverStats(self._solution.attr,
#    1400                                  chain.solver.name())
#
# SolverError: Solver 'MOSEK' failed. Try another solver, or solve with verbose=True for more information.

# %% [markdown]
# ### Case 9
# ### Proposed Control
# ### Minimize(0),  A_T@P + P@A << 0

# %%
scenario = 'nudge'
case_dict['Nval'] = cal_Nvariable(scenario)
A = generate_Amat(gen_dict, con_dict, case_dict, 'nudge')
#B = generate_Bmat(gen_dict, con_dict, case_dict)

n = A.shape[0]

# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma = 1e-6
Q = np.eye(n)* gamma

if case_dict['Ngen'] == 2:
    U = np.array([0.05, 0.0005, -0.0005]).T
elif case_dict['Ngen'] == 3:
    U = np.array([0.05, 0.0005, 0.0005, -0.0005]).T
#bias = LN.norm(np.dot(B,U),2)*2*0.05

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]
constraints = [P >> Q, A.T @ P + P@A << 0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(0)

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
prob.solve(solver=cp.MOSEK, verbose = True)

P_value = np.round(P.value, decimals=5)
eig,left_eig_v,right_eig_v = LN.eig(P_value, left= True, right = True)
check_symmetric(P_value)

eig, eig_vec = LN.eig(P_value)
print("Eigen Value of P ")
plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

x = eig.real
y = eig.imag

print("minimum eigenvalue of P:", min(x))
print("maximum eigenvalue of P:", max(x))


plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 09 10:18:50 PM: Your problem has 361 variables, 2 constraints, and 0 parameters.
# (CVXPY) Mar 09 10:18:50 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 09 10:18:50 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 09 10:18:50 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 09 10:18:50 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 09 10:18:50 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 09 10:18:50 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 09 10:18:50 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 09 10:18:50 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 09 10:18:50 PM: Applying reduction MOSEK
# (CVXPY) Mar 09 10:18:50 PM: Finished problem compilation (took 4.849e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 09 10:18:50 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 09 10:18:50 PM: Problem
# (CVXPY) Mar 09 10:18:50 PM:   Name                   :
# (CVXPY) Mar 09 10:18:50 PM:   Objective sense        : maximize
# (CVXPY) Mar 09 10:18:50 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 09 10:18:50 PM:   Constraints            : 190
# (CVXPY) Mar 09 10:18:50 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 09 10:18:50 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 09 10:18:50 PM:   Cones                  : 0
# (CVXPY) Mar 09 10:18:50 PM:   Scalar variables       : 0
# (CVXPY) Mar 09 10:18:50 PM:   Matrix variables       : 2
# (CVXPY) Mar 09 10:18:50 PM:   Integer variables      : 0
# (CVXPY) Mar 09 10:18:50 PM:
# (CVXPY) Mar 09 10:18:50 PM: Optimizer started.
# (CVXPY) Mar 09 10:18:50 PM: Presolve started.
# (CVXPY) Mar 09 10:18:50 PM: Linear dependency checker started.
# (CVXPY) Mar 09 10:18:50 PM: Linear dependency checker terminated.
# (CVXPY) Mar 09 10:18:50 PM: Eliminator started.
# (CVXPY) Mar 09 10:18:50 PM: Freed constraints in eliminator : 0
# (CVXPY) Mar 09 10:18:50 PM: Eliminator terminated.
# (CVXPY) Mar 09 10:18:50 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Mar 09 10:18:50 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Mar 09 10:18:50 PM: Lin. dep.  - number                 : 0
# (CVXPY) Mar 09 10:18:50 PM: Presolve terminated. Time: 0.00
# (CVXPY) Mar 09 10:18:50 PM: GP based matrix reordering started.
# (CVXPY) Mar 09 10:18:50 PM: GP based matrix reordering terminated.
# (CVXPY) Mar 09 10:18:50 PM: Problem
# (CVXPY) Mar 09 10:18:50 PM:   Name                   :
# (CVXPY) Mar 09 10:18:50 PM:   Objective sense        : maximize
# (CVXPY) Mar 09 10:18:50 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 09 10:18:50 PM:   Constraints            : 190
# (CVXPY) Mar 09 10:18:50 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 09 10:18:50 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 09 10:18:50 PM:   Cones                  : 0
# (CVXPY) Mar 09 10:18:50 PM:   Scalar variables       : 0
# (CVXPY) Mar 09 10:18:50 PM:   Matrix variables       : 2
# (CVXPY) Mar 09 10:18:50 PM:   Integer variables      : 0
# (CVXPY) Mar 09 10:18:50 PM:
# (CVXPY) Mar 09 10:18:50 PM: Optimizer  - threads                : 8
# (CVXPY) Mar 09 10:18:50 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Mar 09 10:18:50 PM: Optimizer  - Constraints            : 190
# (CVXPY) Mar 09 10:18:50 PM: Optimizer  - Cones                  : 0
# (CVXPY) Mar 09 10:18:50 PM: Optimizer  - Scalar variables       : 0                 conic                  : 0
# (CVXPY) Mar 09 10:18:50 PM: Optimizer  - Semi-definite variables: 2                 scalarized             : 380
# (CVXPY) Mar 09 10:18:50 PM: Factor     - setup time             : 0.00              dense det. time        : 0.00
# (CVXPY) Mar 09 10:18:50 PM: Factor     - ML order time          : 0.00              GP order time          : 0.00
# (CVXPY) Mar 09 10:18:50 PM: Factor     - nonzeros before factor : 1.81e+04          after factor           : 1.81e+04
# (CVXPY) Mar 09 10:18:50 PM: Factor     - dense dim.             : 0                 flops                  : 2.97e+06
# (CVXPY) Mar 09 10:18:50 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Mar 09 10:18:50 PM: 0   1.8e+00  1.0e+00  1.0e+00  0.00e+00   1.900000000e-05   0.000000000e+00   1.0e+00  0.01
# (CVXPY) Mar 09 10:18:50 PM: 1   3.1e-01  1.7e-01  7.0e-02  1.00e+00   8.325366259e-06   0.000000000e+00   1.7e-01  0.03
# (CVXPY) Mar 09 10:18:50 PM: 2   7.5e-02  4.1e-02  8.3e-03  1.00e+00   5.020861848e-06   0.000000000e+00   4.1e-02  0.03
# (CVXPY) Mar 09 10:18:50 PM: 3   1.2e-02  6.6e-03  5.4e-04  1.00e+00   2.719521206e-06   0.000000000e+00   6.6e-03  0.03
# (CVXPY) Mar 09 10:18:50 PM: 4   1.8e-03  9.9e-04  3.2e-05  1.00e+00   8.947996827e-07   0.000000000e+00   9.9e-04  0.03
# (CVXPY) Mar 09 10:18:50 PM: 5   1.4e-04  7.6e-05  6.8e-07  9.99e-01   1.773766083e-07   0.000000000e+00   7.6e-05  0.03
# (CVXPY) Mar 09 10:18:50 PM: 6   2.6e-05  1.4e-05  5.5e-08  9.99e-01   3.974400995e-08   0.000000000e+00   1.4e-05  0.03
# (CVXPY) Mar 09 10:18:50 PM: 7   1.2e-06  6.7e-07  5.6e-10  9.99e-01   2.695729397e-09   0.000000000e+00   6.7e-07  0.03
# (CVXPY) Mar 09 10:18:50 PM: 8   3.4e-08  1.9e-08  2.6e-12  1.00e+00   6.583583025e-11   0.000000000e+00   1.9e-08  0.03
# (CVXPY) Mar 09 10:18:50 PM: 9   1.3e-09  7.3e-10  1.9e-14  1.00e+00   2.441781081e-12   0.000000000e+00   7.0e-10  0.03
# (CVXPY) Mar 09 10:18:50 PM: Optimizer terminated. Time: 0.03
# (CVXPY) Mar 09 10:18:50 PM:
# (CVXPY) Mar 09 10:18:50 PM:
# (CVXPY) Mar 09 10:18:50 PM: Interior-point solution summary
# (CVXPY) Mar 09 10:18:50 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Mar 09 10:18:50 PM:   Solution status : OPTIMAL
# (CVXPY) Mar 09 10:18:50 PM:   Primal.  obj: 2.4417810812e-12    nrm: 8e-01    Viol.  con: 1e-07    barvar: 0e+00
# (CVXPY) Mar 09 10:18:50 PM:   Dual.    obj: 0.0000000000e+00    nrm: 4e+00    Viol.  con: 0e+00    barvar: 8e-10
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 09 10:18:50 PM: Problem status: optimal
# (CVXPY) Mar 09 10:18:50 PM: Optimal value: 0.000e+00
# (CVXPY) Mar 09 10:18:50 PM: Compilation took 4.849e-02 seconds
# (CVXPY) Mar 09 10:18:50 PM: Solver (including time spent in interface) took 6.197e-02 seconds
# Matrix is symmetric
# Eigen Value of P
# minimum eigenvalue of P: 0.001270908936303045
# maximum eigenvalue of P: 6.021234981937006

# %% [markdown]
# ### Case 10
# ### droop System
# ### Bound RMS Methods

# %%
A = generate_Amat(gen_dict, con_dict, case_dict, 'droop')
B = generate_Bmat(gen_dict, con_dict, case_dict)
B = B/100000
n = A.shape[0]
m = B.shape[1]
# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma2 = cp.Variable()
Q = np.eye(n)
C = np.array([0, 1, 0, 0, 0, 1, 0, 0, 0])

U = np.array([0.05, 0.0005, -0.0005]).T

bias = LN.norm(np.dot(B,U),2)

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]

M = cp.bmat([[A.T @ P + P@A +C.T@C, P@B], [B.T@P, -gamma2*np.eye(m)]])
constraints = [P >> 1e-6*np.eye(n), M <<0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(0)

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
prob.solve(solver=cp.MOSEK, verbose = True)

try:
    P_value = np.round(P.value, decimals=5)
    eig,left_eig_v,right_eig_v = LN.eig(P_value, left= True, right = True)
    check_symmetric(P_value)

    eig, eig_vec = LN.eig(P_value)
    print("Eigen Value of P ")
    plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
    plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

    x = eig.real
    y = eig.imag

    print("minimum eigenvalue of P:", min(x))
    print("maximum eigenvalue of P:", max(x))


    plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
except:
    print("Solution Infeasible")
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 09 03:45:44 PM: Your problem has 82 variables, 2 constraints, and 0 parameters.
# (CVXPY) Mar 09 03:45:44 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 09 03:45:44 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 09 03:45:44 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 09 03:45:44 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 09 03:45:44 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 09 03:45:44 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 09 03:45:44 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 09 03:45:44 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 09 03:45:44 PM: Applying reduction MOSEK
# (CVXPY) Mar 09 03:45:44 PM: Finished problem compilation (took 2.102e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 09 03:45:44 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 09 03:45:44 PM: Problem
# (CVXPY) Mar 09 03:45:44 PM:   Name                   :
# (CVXPY) Mar 09 03:45:44 PM:   Objective sense        : maximize
# (CVXPY) Mar 09 03:45:44 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 09 03:45:44 PM:   Constraints            : 46
# (CVXPY) Mar 09 03:45:44 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 09 03:45:44 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 09 03:45:44 PM:   Cones                  : 0
# (CVXPY) Mar 09 03:45:44 PM:   Scalar variables       : 0
# (CVXPY) Mar 09 03:45:44 PM:   Matrix variables       : 2
# (CVXPY) Mar 09 03:45:44 PM:   Integer variables      : 0
# (CVXPY) Mar 09 03:45:44 PM:
# (CVXPY) Mar 09 03:45:44 PM: Optimizer started.
# (CVXPY) Mar 09 03:45:44 PM: Presolve started.
# (CVXPY) Mar 09 03:45:44 PM: Linear dependency checker started.
# (CVXPY) Mar 09 03:45:44 PM: Linear dependency checker terminated.
# (CVXPY) Mar 09 03:45:44 PM: Eliminator started.
# (CVXPY) Mar 09 03:45:44 PM: Freed constraints in eliminator : 0
# (CVXPY) Mar 09 03:45:44 PM: Eliminator terminated.
# (CVXPY) Mar 09 03:45:44 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Mar 09 03:45:44 PM: Lin. dep.  - tries                  : 1                 time                   : 0.02
# (CVXPY) Mar 09 03:45:44 PM: Lin. dep.  - number                 : 0
# (CVXPY) Mar 09 03:45:44 PM: Presolve terminated. Time: 0.02
# (CVXPY) Mar 09 03:45:44 PM: Problem
# (CVXPY) Mar 09 03:45:44 PM:   Name                   :
# (CVXPY) Mar 09 03:45:44 PM:   Objective sense        : maximize
# (CVXPY) Mar 09 03:45:44 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 09 03:45:44 PM:   Constraints            : 46
# (CVXPY) Mar 09 03:45:44 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 09 03:45:44 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 09 03:45:44 PM:   Cones                  : 0
# (CVXPY) Mar 09 03:45:44 PM:   Scalar variables       : 0
# (CVXPY) Mar 09 03:45:44 PM:   Matrix variables       : 2
# (CVXPY) Mar 09 03:45:44 PM:   Integer variables      : 0
# (CVXPY) Mar 09 03:45:44 PM:
# (CVXPY) Mar 09 03:45:44 PM: Optimizer  - threads                : 8
# (CVXPY) Mar 09 03:45:44 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Mar 09 03:45:44 PM: Optimizer  - Constraints            : 46
# (CVXPY) Mar 09 03:45:44 PM: Optimizer  - Cones                  : 0
# (CVXPY) Mar 09 03:45:44 PM: Optimizer  - Scalar variables       : 0                 conic                  : 0
# (CVXPY) Mar 09 03:45:44 PM: Optimizer  - Semi-definite variables: 2                 scalarized             : 123
# (CVXPY) Mar 09 03:45:44 PM: Factor     - setup time             : 0.00              dense det. time        : 0.00
# (CVXPY) Mar 09 03:45:44 PM: Factor     - ML order time          : 0.00              GP order time          : 0.00
# (CVXPY) Mar 09 03:45:44 PM: Factor     - nonzeros before factor : 1081              after factor           : 1081
# (CVXPY) Mar 09 03:45:44 PM: Factor     - dense dim.             : 0                 flops                  : 7.89e+04
# (CVXPY) Mar 09 03:45:44 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Mar 09 03:45:44 PM: 0   3.0e+00  3.0e+00  1.7e+01  0.00e+00   1.800000900e+01   0.000000000e+00   1.0e+00  0.02
# (CVXPY) Mar 09 03:45:44 PM: 1   6.5e-01  6.5e-01  1.1e+01  -1.19e+00  3.496212853e+01   0.000000000e+00   2.2e-01  0.03
# (CVXPY) Mar 09 03:45:44 PM: 2   1.7e-01  1.7e-01  1.7e+01  -2.22e+00  4.739071523e+02   0.000000000e+00   5.5e-02  0.03
# (CVXPY) Mar 09 03:45:44 PM: 3   4.6e-02  4.6e-02  6.1e+00  -1.67e+00  5.881267450e+02   0.000000000e+00   1.5e-02  0.03
# (CVXPY) Mar 09 03:45:44 PM: 4   1.1e-02  1.1e-02  1.5e+00  -2.92e-01  5.976933531e+02   0.000000000e+00   3.8e-03  0.03
# (CVXPY) Mar 09 03:45:44 PM: 5   1.6e-03  1.6e-03  5.4e-01  -9.04e-01  3.501746891e+03   0.000000000e+00   5.4e-04  0.03
# (CVXPY) Mar 09 03:45:44 PM: 6   1.6e-04  1.6e-04  1.8e-01  -9.76e-01  3.698028219e+04   0.000000000e+00   5.5e-05  0.03
# (CVXPY) Mar 09 03:45:44 PM: 7   3.3e-05  3.3e-05  8.1e-02  -9.99e-01  1.871406688e+05   0.000000000e+00   1.1e-05  0.03
# (CVXPY) Mar 09 03:45:44 PM: 8   2.1e-06  2.1e-06  2.3e-02  -1.00e+00  3.530350822e+06   0.000000000e+00   7.1e-07  0.03
# (CVXPY) Mar 09 03:45:44 PM: 9   4.3e-08  4.3e-08  3.2e-03  -1.00e+00  1.745825438e+08   0.000000000e+00   1.4e-08  0.03
# (CVXPY) Mar 09 03:45:44 PM: 10  3.6e-09  3.6e-09  9.4e-04  -1.00e+00  2.124143840e+09   0.000000000e+00   1.2e-09  0.03
# (CVXPY) Mar 09 03:45:44 PM: 11  2.4e-10  3.5e-10  2.4e-04  -1.00e+00  3.242951214e+10   0.000000000e+00   7.9e-11  0.03
# (CVXPY) Mar 09 03:45:44 PM: 12  1.3e-11  3.8e-09  5.7e-05  -1.00e+00  6.306295539e+11   0.000000000e+00   4.1e-12  0.03
# (CVXPY) Mar 09 03:45:44 PM: 13  7.6e-13  1.1e-07  1.4e-05  -1.01e+00  1.083087282e+13   0.000000000e+00   2.4e-13  0.03
# (CVXPY) Mar 09 03:45:44 PM: Optimizer terminated. Time: 0.03
# (CVXPY) Mar 09 03:45:44 PM:
# (CVXPY) Mar 09 03:45:44 PM:
# (CVXPY) Mar 09 03:45:44 PM: Interior-point solution summary
# (CVXPY) Mar 09 03:45:44 PM:   Problem status  : DUAL_INFEASIBLE
# (CVXPY) Mar 09 03:45:44 PM:   Solution status : DUAL_INFEASIBLE_CER
# (CVXPY) Mar 09 03:45:44 PM:   Primal.  obj: 1.4131348289e+00    nrm: 4e-01    Viol.  con: 6e-11    barvar: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 09 03:45:44 PM: Problem status: infeasible
# (CVXPY) Mar 09 03:45:44 PM: Optimal value: inf
# (CVXPY) Mar 09 03:45:44 PM: Compilation took 2.102e-02 seconds
# (CVXPY) Mar 09 03:45:44 PM: Solver (including time spent in interface) took 5.300e-02 seconds
# Solution Infeasible

# %% [markdown]
# ### Case 11
# ### Switched System
# ### Common Lyapunov

# %%
A_droop = generate_Amat(gen_dict, con_dict, case_dict, 'droop')
A_secPI = generate_Amat(gen_dict, con_dict, case_dict, 'secPI')
B = generate_Bmat(gen_dict, con_dict, case_dict)

n = A.shape[0]
m = B.shape[1]
# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma2 = cp.Variable()
Q = np.eye(n)*1e-6
C = np.array([0, 1, 0, 0, 0, 1, 0, 0, 0])

U = np.array([0.05, 0.0005, -0.0005]).T

bias = LN.norm(np.dot(B,U),2)

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]

constraints = [P >> 0,  A_droop.T @ P + P@A_droop - P @B @ B.T @ P + Q << 0 ]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(0)

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
prob.solve(solver=cp.MOSEK, verbose = True)

try:
    P_value = np.round(P.value, decimals=5)
    eig,left_eig_v,right_eig_v = LN.eig(P_value, left= True, right = True)
    check_symmetric(P_value)

    eig, eig_vec = LN.eig(P_value)
    print("Eigen Value of P ")
    plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
    plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

    x = eig.real
    y = eig.imag

    print("minimum eigenvalue of P:", min(x))
    print("maximum eigenvalue of P:", max(x))


    plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
except:
    print("Solution Infeasible")
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 09 05:26:38 PM: Your problem has 169 variables, 2 constraints, and 0 parameters.
# (CVXPY) Mar 09 05:26:38 PM: It is compliant with the following grammars:
# (CVXPY) Mar 09 05:26:38 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 09 05:26:38 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 33>()
#      27 prob = cp.Problem(obj, constraints)
#      29 # Create a SolverOptions object and set the tolerance to 1e-6
#      30 # Solve the problem with the specified options
#      31
#      32 #prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
# ---> 33 prob.solve(solver=cp.MOSEK, verbose = True)
#      35 try:
#      36     P_value = np.round(P.value, decimals=5)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:493, in Problem.solve(self, *args, **kwargs)
#     491 else:
#     492     solve_func = Problem._solve
# --> 493 return solve_func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:1054, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1051         self.unpack(chain.retrieve(soln))
#    1052         return self.value
# -> 1054 data, solving_chain, inverse_data = self.get_problem_data(
#    1055     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1056 )
#    1058 if verbose:
#    1059     print(_NUM_SOLVER_STR)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:631, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     629 if key != self._cache.key:
#     630     self._cache.invalidate()
# --> 631     solving_chain = self._construct_chain(
#     632         solver=solver, gp=gp,
#     633         enforce_dpp=enforce_dpp,
#     634         ignore_dpp=ignore_dpp,
#     635         canon_backend=canon_backend,
#     636         solver_opts=solver_opts)
#     637     self._cache.key = key
#     638     self._cache.solving_chain = solving_chain
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:883, in Problem._construct_chain(self, solver, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#     881 candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#     882 self._sort_candidate_solvers(candidate_solvers)
# --> 883 return construct_solving_chain(self, candidate_solvers, gp=gp,
#     884                                enforce_dpp=enforce_dpp,
#     885                                ignore_dpp=ignore_dpp,
#     886                                canon_backend=canon_backend,
#     887                                solver_opts=solver_opts)
#
# File ~\anaconda3\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:184, in construct_solving_chain(problem, candidates, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#     182 if len(problem.variables()) == 0:
#     183     return SolvingChain(reductions=[ConstantSolver()])
# --> 184 reductions = _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     186 # Process DPP status of the problem.
#     187 dpp_context = 'dcp' if not gp else 'dgp'
#
# File ~\anaconda3\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:102, in _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#      99     elif problem.is_dqcp():
#     100         append += ("\nHowever, the problem does follow DQCP rules. "
#     101                    "Consider calling solve() with `qcp=True`.")
# --> 102     raise DCPError(
#     103         "Problem does not follow DCP rules. Specifically:\n" + append)
#     104 elif gp and not problem.is_dgp():
#     105     append = build_non_disciplined_error_msg(problem, 'DGP')
#
# DCPError: Problem does not follow DCP rules. Specifically:
# The following constraints are not DCP:
# Promote(0.0, (13, 13)) + -[[-7.59070897e-04  0.00000000e+00  0.00000000e+00 -9.97570973e+01
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -2.49392743e+01  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 7.59070897e-02  0.00000000e+00  0.00000000e+00 -2.42902687e+01
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -6.07256718e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -5.60000000e+01
#   -5.00000000e-02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00 -2.20000000e+01
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+02
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 7.59070897e-02  0.00000000e+00  0.00000000e+00 -2.42902687e+01
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -6.07256718e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00
#    0.00000000e+00 -1.40000000e+01 -5.00000000e-02  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    1.00000000e+00 -1.10000000e+01  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  2.50000000e+01  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]] @ var127 + var127 @ [[-7.59070897e-04  7.59070897e-02  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  7.59070897e-02
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [-9.97570973e+01 -2.42902687e+01 -5.60000000e+01 -2.20000000e+01
#    1.00000000e+02  0.00000000e+00  0.00000000e+00 -2.42902687e+01
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -5.00000000e-02  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  1.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [-2.49392743e+01 -6.07256718e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00 -6.07256718e+00
#   -1.40000000e+01 -1.10000000e+01  2.50000000e+01  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -5.00000000e-02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]] + -var127 @ [[-7.59070897e-02  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.42902687e+01 -1.00000000e+02  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 6.07256718e+00  0.00000000e+00 -2.50000000e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]] @ [[-7.59070897e-02  0.00000000e+00  0.00000000e+00  2.42902687e+01
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  6.07256718e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -1.00000000e+02
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -2.50000000e+01  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]] @ var127 + [[1.e-06 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 1.e-06 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 1.e-06 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 1.e-06 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 1.e-06 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 1.e-06 0.e+00 0.e+00 0.e+00 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 1.e-06 0.e+00 0.e+00 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 1.e-06 0.e+00 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 1.e-06 0.e+00
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 1.e-06
#   0.e+00 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00
#   1.e-06 0.e+00 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00
#   0.e+00 1.e-06 0.e+00]
#  [0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00
#   0.e+00 0.e+00 1.e-06]] >> 0 , because the following subexpressions are not:
# |--  var127 @ [[-7.59070897e-02  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.42902687e+01 -1.00000000e+02  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 6.07256718e+00  0.00000000e+00 -2.50000000e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00]] @ [[-7.59070897e-02  0.00000000e+00  0.00000000e+00  2.42902687e+01
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  6.07256718e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -1.00000000e+02
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -2.50000000e+01  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]] @ var127

# %%
Q = A.T@P.value + P.value@A
check_symmetric(Q)
table1 = tabulate.tabulate(Q, tablefmt='html')
print("symmetric A.T@P+P@A Table")
table1
LN.eigvals(Q)
# Out:
# (0, 12) and (12, 0) entries are not equal: 0.03402963908344003 != 0.03402963908343992
# (3, 12) and (12, 3) entries are not equal: -0.07293393891128314 != -0.07293393891128312
# (6, 12) and (12, 6) entries are not equal: -0.004785029571995947 != -0.00478502957199594
# symmetric A.T@P+P@A Table
# array([-1.44600245e+00+0.j, -1.17309599e+00+0.j, -9.28399711e-01+0.j,
#        -8.64753658e-01+0.j, -7.10410775e-01+0.j, -4.64626983e-01+0.j,
#        -3.32544696e-01+0.j, -1.25586815e-01+0.j, -2.65046178e-01+0.j,
#        -3.68197265e-02+0.j, -1.57732643e-02+0.j,  5.23113607e-11+0.j,
#         4.18701365e-10+0.j])

# %%
Q = A_secPI.T@P.value + P.value@A_secPI
table1 = tabulate.tabulate(Q, tablefmt='html')
check_symmetric(Q)
print("symmetric A.T@P+P@A Table")
table1
LN.eigvals(Q)
# Out:
# (0, 12) and (12, 0) entries are not equal: 0.9130183710019937 != 0.9130183710019936
# (3, 12) and (12, 3) entries are not equal: -0.07572123978210697 != -0.07572123978210696
# symmetric A.T@P+P@A Table
# array([-2.26699841e+00+0.j,  1.36986510e+00+0.j, -1.35864702e+00+0.j,
#        -9.99102445e-01+0.j, -6.57430138e-01+0.j,  6.98653863e-01+0.j,
> 0.00300763</td><td style="text-align: right;">-0.422628 </td><td style="text-align: right;"> 0.190958 </td><td style="text-align: right;"> 0.352518  </td><td style="text-align: right;"> 0.17709  </td></tr>\n<tr><td style="text-align: right;"> 0.452546  </td><td style="text-align: right;"> 0.00194888</td><td style="text-align: right;">-0.0690101</td><td style="text-align: right;">-0.516663 </td><td style="text-align: right;">-0.37538   </td><td style="text-align: right;"> 0         </td><td style="text-align: right;"> 0        </td><td style="text-align: right;"> 0.00194888</td><td style="text-align: right;">-0.244696  </td><td style="text-align: right;"> 0.277444 </td><td style="text-align: right;">-0.0771855</td><td style="text-align: right;"> 0         </td><td style="text-align: right;"> 0        </td></tr>\n<tr><td style="text-align: right;"> 1.22681   </td><td style="text-align: right;"> 0.253058  </td><td style="text-align: right;"> 0.733334 </td><td style="text-align: right;"> 0.136366 </td><td style="text-align: right;">-1.43846   </td><td style="text-align: right;"> 0         </td>< ...

# %% [markdown]
# ### Case
# ### Lyapunov Function
# ### Fine the optimal gain kc1

# %%
scenario = 'nudge'
case_dict['Nval'] = cal_Nvariable(scenario)
A = generate_Amat(gen_dict, con_dict, case_dict, scenario)
A_secPI = generate_Amat(gen_dict, con_dict, case_dict, 'secondPI')
A_droop = generate_Amat(gen_dict, con_dict, case_dict, 'droop')

B = generate_Bmat(gen_dict, con_dict, case_dict)

n = A.shape[0]
m = B.shape[1]
# Define the LMI variables
P = cp.Variable((n,n), symmetric = True)
gamma2 = cp.Variable()
Q = np.eye(n)*1e-5
C = np.array([0, 1, 0, 0, 0, 1, 0, 0, 0])

U = np.array([0.05, 0.0005, 0, -0.0005]).T

bias = LN.norm(np.dot(B,U),2)

# Define the constraints for the LMI
#constraints = [P >>0, A.T @ P + P@A + Q << 0]

kc1 = cp.Variable()
idx_list = []
constraints = []

varA = cp.Variable((n,n))
idx_list = []
for i in range(case_dict['Ngen']):
    idx = 1 + i*case_dict['Nval']+4
    idx_list.append(idx)


# for i in range(n):
#     for j in range(n):
#         constraints += [varA[i,j] == A[i,j]]        
        
constraints += [P >> Q,  varA.T @ P + P@varA << 0, kc1 >= 0.001]
#constraints += [A_secPI @ P + P@A_secPI <<0]

# Define the objective for the LMI optimization problem
#obj = cp.Minimize(cp.trace(P))
obj = cp.Minimize(cp.trace(P))

# Solve the LMI optimization problem
prob = cp.Problem(obj, constraints)

# Create a SolverOptions object and set the tolerance to 1e-6
# Solve the problem with the specified options

#prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
prob.solve(solver=cp.MOSEK, verbose = True)

try:
    P_value = np.round(P.value, decimals=5)
    eig,left_eig_v,right_eig_v = LN.eig(P_value, left= True, right = True)
    check_symmetric(P_value)

    eig, eig_vec = LN.eig(P.value)
    print("Eigen Value of P ")
    plt.axvline(x=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')
    plt.axhline(y=0, color = 'black', alpha = 0.3, linewidth = 0.7, linestyle='--')

    x = eig.real
    y = eig.imag

    print("minimum eigenvalue of P:", min(x))
    print("maximum eigenvalue of P:", max(x))


    plt.scatter(x,y, s = 20, c = 'r', alpha = 0.8)
except:
    print("Solution Infeasible")
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 23 02:59:15 PM: Your problem has 513 variables, 3 constraints, and 0 parameters.
# (CVXPY) Mar 23 02:59:15 PM: It is compliant with the following grammars:
# (CVXPY) Mar 23 02:59:15 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 23 02:59:15 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 53>()
#      47 prob = cp.Problem(obj, constraints)
#      49 # Create a SolverOptions object and set the tolerance to 1e-6
#      50 # Solve the problem with the specified options
#      51
#      52 #prob.solve(solver=cp.MOSEK, verbose=True) #, options=options)
# ---> 53 prob.solve(solver=cp.MOSEK, verbose = True)
#      55 try:
#      56     P_value = np.round(P.value, decimals=5)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:493, in Problem.solve(self, *args, **kwargs)
#     491 else:
#     492     solve_func = Problem._solve
# --> 493 return solve_func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:1054, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1051         self.unpack(chain.retrieve(soln))
#    1052         return self.value
# -> 1054 data, solving_chain, inverse_data = self.get_problem_data(
#    1055     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1056 )
#    1058 if verbose:
#    1059     print(_NUM_SOLVER_STR)
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:631, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     629 if key != self._cache.key:
#     630     self._cache.invalidate()
# --> 631     solving_chain = self._construct_chain(
#     632         solver=solver, gp=gp,
#     633         enforce_dpp=enforce_dpp,
#     634         ignore_dpp=ignore_dpp,
#     635         canon_backend=canon_backend,
#     636         solver_opts=solver_opts)
#     637     self._cache.key = key
#     638     self._cache.solving_chain = solving_chain
#
# File ~\anaconda3\lib\site-packages\cvxpy\problems\problem.py:883, in Problem._construct_chain(self, solver, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#     881 candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#     882 self._sort_candidate_solvers(candidate_solvers)
# --> 883 return construct_solving_chain(self, candidate_solvers, gp=gp,
#     884                                enforce_dpp=enforce_dpp,
#     885                                ignore_dpp=ignore_dpp,
#     886                                canon_backend=canon_backend,
#     887                                solver_opts=solver_opts)
#
# File ~\anaconda3\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:184, in construct_solving_chain(problem, candidates, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#     182 if len(problem.variables()) == 0:
#     183     return SolvingChain(reductions=[ConstantSolver()])
# --> 184 reductions = _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     186 # Process DPP status of the problem.
#     187 dpp_context = 'dcp' if not gp else 'dgp'
#
# File ~\anaconda3\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:102, in _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#      99     elif problem.is_dqcp():
#     100         append += ("\nHowever, the problem does follow DQCP rules. "
#     101                    "Consider calling solve() with `qcp=True`.")
# --> 102     raise DCPError(
#     103         "Problem does not follow DCP rules. Specifically:\n" + append)
#     104 elif gp and not problem.is_dgp():
#     105     append = build_non_disciplined_error_msg(problem, 'DGP')
#
# DCPError: Problem does not follow DCP rules. Specifically:
# The following constraints are not DCP:
# Promote(0.0, (16, 16)) + -var15282.T @ var15279 + var15279 @ var15282 >> 0 , because the following subexpressions are not:
# |--  var15282.T @ var15279
# |--  var15279 @ var15282

# %%
kc1.value
# Out:
# array(0.1)
